# %% [markdown]
# # InetCampus operation - initial email servers budget study #

# %% [markdown]
# ----------------------------------------------------------------

# %% [markdown]
# The servers could be classified in incoming mails servers and outbound mails servers.
#
# The analysis should also take in consideration that the company has its own use of emails to stablish communications with the customers and internal emails between new employees and the rest of the company should also be considered.

# %% [markdown]
# InetCampus stores the emails and their characteristics for five years, passed this time the information is deleted.
